# %%
# import stuff here
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

from sklearn.metrics import mean_squared_error
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import numpy as np
from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose
import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import boto3
import pandas as pd
from sagemaker import get_execution_role

def list_data(folder):
    """
    List all available data sets in the folder
    
    """
    s3 = boto3.resource('s3')
    bucket='cp-hackathon-data'
    hackathon_data = s3.Bucket(bucket)
    keys = []
    for obj in hackathon_data.objects.filter(Prefix=folder):
        keys.append(obj.key)
    return keys
def get_data(key):
    role = get_execution_role()
    bucket='cp-hackathon-data'
    data_location = 's3://{}/{}'.format(bucket, key)
    return pd.read_csv(data_location)

# %%
list_data('RedCross')
# Out:
# ['RedCross/',
#  'RedCross/ovitrap_data.csv',
#  'RedCross/ovitrap_data_monthly_province.csv',
#  'RedCross/weather_data_monthly_province.csv']

# %%
mosq = get_data('RedCross/ovitrap_data_monthly_province.csv').sort_values(['adm_level', 'date'])
# Out:
# Couldn't call 'get_role' to get Role ARN from role name cp-sagemaker-hackathon-role to get Role path.

# %%
mosq['date'] = pd.to_datetime(mosq.date).dt.date

# %%
weather = get_data('RedCross/weather_data_monthly_province.csv')
# Out:
# Couldn't call 'get_role' to get Role ARN from role name cp-sagemaker-hackathon-role to get Role path.

# %%
weather['date'] = pd.to_datetime(weather['date']).dt.date

# %%
weather.rename(mapper={
    'JAXA_GPM_L3_GSMaP_v6_operational_hourlyPrecipRateGC':'jaxa_rainfall',
    'MODIS_006_MOD11A1_LST_Day_1km': 'land_surface_temperature_day',
    'MODIS_006_MYD13A1_EVI':'vegetation_index',
    'MODIS_006_MOD11A1_LST_Night_1km': 'land_surface_temperature_night',
    'NASA_FLDAS_NOAH01_C_GL_M_V001_Qair_f_tavg': 'specific_humidity',
    'NASA_FLDAS_NOAH01_C_GL_M_V001_Rainf_f_tavg': 'fldas_rainfall',
    'NASA_FLDAS_NOAH01_C_GL_M_V001_SoilMoi00_10cm_tavg': 'soil_moisture',
    'NASA_FLDAS_NOAH01_C_GL_M_V001_SoilTemp00_10cm_tavg': 'soil_temperature',
    'NASA_FLDAS_NOAH01_C_GL_M_V001_Tair_f_tavg': 'air_temperature',
    'NASA_FLDAS_NOAH01_C_GL_M_V001_Wind_f_tavg': 'wind_speed'
                      },
               axis=1,
               inplace=True)

# %% [markdown]
# # focusing on Pangasinan province

# %%
mosq = weather.merge(mosq, on=['adm_level', 'date'], how='left')

# %%
mosq.loc[mosq.count_ovi>0].corr().sort_values('mean_ovi')
# Out:
#                                 jaxa_rainfall  land_surface_temperature_day  \
# error_relative_ovi                  -0.043448                      0.019026
# land_surface_temperature_day        -0.173665                      1.000000
# soil_temperature                    -0.175397                      0.758672
# count_ovi                           -0.010166                      0.020088
# land_surface_temperature_night      -0.125168                      0.600960
# air_temperature                      0.015681                      0.542546
# jaxa_rainfall                        1.000000                     -0.173665
# wind_speed                          -0.007207                     -0.316798
# specific_humidity                    0.338619                      0.281040
# fldas_rainfall                       0.783256                     -0.115288
# soil_moisture                        0.477639                     -0.172629
# vegetation_index                     0.047291                     -0.611760
# error_ovi                            0.015482                     -0.141915
# mean_ovi                             0.038549                     -0.222230
#
#                                 land_surface_temperature_night  \
# error_relative_ovi                                   -0.043671
# land_surface_temperature_day                          0.600960
# soil_temperature                                      0.837801
# count_ovi                                            -0.041350
# land_surface_temperature_night                        1.000000
# air_temperature                                       0.868089
# jaxa_rainfall                                        -0.125168
# wind_speed                                           -0.003427
# specific_humidity                                     0.652772
# fldas_rainfall                                       -0.016092
# soil_moisture                                        -0.029635
# vegetation_index                                     -0.087791
# error_ovi                                            -0.054209
# mean_ovi                                             -0.058370
#
#                                 vegetation_index  specific_humidity  \
# error_relative_ovi                     -0.080227          -0.141662
# land_surface_temperature_day           -0.611760           0.281040
# soil_temperature                       -0.240100           0.530694
# count_ovi                              -0.075432          -0.007945
# land_surface_temperature_night         -0.087791           0.652772
# air_temperature                         0.059572           0.790790
# jaxa_rainfall                           0.047291           0.338619
# wind_speed                              0.074622          -0.012287
# specific_humidity                       0.087972           1.000000
# fldas_rainfall                         -0.021826           0.510197
# soil_moisture                           0.058447           0.521520
# vegetation_index                        1.000000           0.087972
# error_ovi                               0.145805          -0.013353
# mean_ovi                                0.263520           0.083817
#
#                                 fldas_rainfall  soil_moisture  \
# error_relative_ovi                   -0.091112      -0.124182
# land_surface_temperature_day         -0.115288      -0.172629
# soil_temperature                     -0.101343      -0.245466
# count_ovi                            -0.018656       0.030972
# land_surface_temperature_night       -0.016092      -0.029635
# air_temperature                       0.147189       0.048218
# jaxa_rainfall                         0.783256       0.477639
# wind_speed                            0.069932      -0.002745
# specific_humidity                     0.510197       0.521520
# fldas_rainfall                        1.000000       0.625907
# soil_moisture                         0.625907       1.000000
# vegetation_index                     -0.021826       0.058447
# error_ovi                             0.023887       0.016068
# mean_ovi                              0.115017       0.139250
#
#                                 soil_temperature  air_temperature  wind_speed  \
# error_relative_ovi                     -0.035116        -0.090054   -0.071487
# land_surface_temperature_day            0.758672         0.542546   -0.316798
# soil_temperature                        1.000000         0.872140   -0.022720
# count_ovi                              -0.036816        -0.045428   -0.024778
# land_surface_temperature_night          0.837801         0.868089   -0.003427
# air_temperature                         0.872140         1.000000   -0.047220
# jaxa_rainfall                          -0.175397         0.015681   -0.007207
# wind_speed                             -0.022720        -0.047220    1.000000
# specific_humidity                       0.530694         0.790790   -0.012287
# fldas_rainfall                         -0.101343         0.147189    0.069932
# soil_moisture                          -0.245466         0.048218   -0.002745
# vegetation_index                       -0.240100         0.059572    0.074622
# error_ovi                              -0.093973        -0.038749    0.025556
# mean_ovi                               -0.133356        -0.003180    0.067094
#
#                                 count_ovi  mean_ovi  error_ovi  \
# error_relative_ovi              -0.239962 -0.421641   0.517092
# land_surface_temperature_day     0.020088 -0.222230  -0.141915
# soil_temperature                -0.036816 -0.133356  -0.093973
# count_ovi                        1.000000 -0.097539  -0.250023
# land_surface_temperature_night  -0.041350 -0.058370  -0.054209
# air_temperature                 -0.045428 -0.003180  -0.038749
# jaxa_rainfall                   -0.010166  0.038549   0.015482
# wind_speed                      -0.024778  0.067094   0.025556
# specific_humidity               -0.007945  0.083817  -0.013353
# fldas_rainfall                  -0.018656  0.115017   0.023887
# soil_moisture                    0.030972  0.139250   0.016068
# vegetation_index                -0.075432  0.263520   0.145805
# error_ovi                       -0.250023  0.284098   1.000000
# mean_ovi                        -0.097539  1.000000   0.284098
#
#                                 error_relative_ovi
# error_relative_ovi                        1.000000
# land_surface_temperature_day              0.019026
# soil_temperature                         -0.035116
# count_ovi                                -0.239962
# land_surface_temperature_night           -0.043671
# air_temperature                          -0.090054
# jaxa_rainfall                            -0.043448
# wind_speed                               -0.071487
# specific_humidity                        -0.141662
# fldas_rainfall                           -0.091112
# soil_moisture                            -0.124182
# vegetation_index                         -0.080227
# error_ovi                                 0.517092
# mean_ovi                                 -0.421641

# %%
df = mosq.loc[(mosq.adm_level == 'Pangasinan')&(mosq.count_ovi>0)].reset_index()
df.rename(mapper={'index':'old_index'}, axis=1, inplace=True)
train = df.iloc[1:43].set_index('date')
test = df[43:53].set_index('date')

# %%
temp_df =  (
    mosq.loc[(mosq.adm_level == 'Pangasinan')].reset_index()
    .rename(mapper={'index':'old_index'}, axis=1)
)
empty = (
    temp_df
    .loc[temp_df.old_index == 5261]
    .set_index('date')
)

# %%
empty
# Out:
#             old_index   adm_level  jaxa_rainfall  \
# date
# 2016-05-01       5261  Pangasinan       0.102047
#
#             land_surface_temperature_day  land_surface_temperature_night  \
# date
# 2016-05-01                     15468.959                       14878.453
#
#             vegetation_index  specific_humidity  fldas_rainfall  \
# date
# 2016-05-01          3744.314           0.017385         0.00008
#
#             soil_moisture  soil_temperature  air_temperature  wind_speed  \
# date
# 2016-05-01       0.294611         302.86682        301.79465    2.731993
#
#             count_ovi  mean_ovi  error_ovi  error_relative_ovi
# date
# 2016-05-01        0.0       NaN        NaN                 NaN

# %%
decomp = seasonal_decompose(train.mean_ovi, period=6)
decomp.plot()

# %%
sarima_model = SARIMAX(train.mean_ovi,exog = train[['vegetation_index', 'soil_moisture', 'fldas_rainfall']], order=(12,0,0), seasonal_order=(0,0,0,12))
sarima_fit = sarima_model.fit()
pred = sarima_fit.predict(exog=pd.concat([empty, test])[['vegetation_index', 'soil_moisture', 'fldas_rainfall']], start = train.index[-1]+pd.DateOffset(months=1), end = test.index[-1])

# %%
train['pred'] = train.mean_ovi
empty['pred'] = pred[0]
test['pred']=pred[1:]
final_df = pd.concat([train, empty, test]).sort_index()

# %%
sns.set_context({"figure.figsize": (20, 8)})
sns.pointplot(x=final_df.index, y=final_df.pred, color='red')
sns.pointplot(x = final_df.index, y=final_df.mean_ovi, color='black')
plt.xticks(rotation=90)
plt.axhline(y=40, ls=':')

# %%
np.sqrt(mean_squared_error(test.pred, test.mean_ovi))
# Out:
# 5.123682735168567

# %%
#plotting the residuals
res = test.mean_ovi - test.pred
plt.hist(res)
# Out:
# (array([1., 2., 0., 1., 1., 0., 3., 0., 0., 2.]),
#  array([-7.90778773, -6.33846654, -4.76914535, -3.19982417, -1.63050298,
#         -0.06118179,  1.50813939,  3.07746058,  4.64678177,  6.21610295,
#          7.78542414]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # forward chained validation

# %%
# impute empty value with forecasted one
cv_train = pd.concat([train, empty])
cv_train['mean_ovi'] = cv_train.pred
cv_datasets = [[cv_train, test.iloc[0]]]
cv_datasets.extend([[pd.concat([cv_train, test.iloc[0:i]]), test.iloc[i:i+1]] for i in range(1, test.shape[0])])

# %%
def forward_chained_validation(cv_datasets:list, columns:list):
    total_rmse=0
    for dataset in cv_datasets[1:-1]:
        df_train = dataset[0]
        df_test = dataset[1]
        sarima_model = SARIMAX(df_train.mean_ovi, exog = df_train[columns], order=(12,0,0), seasonal_order=(0,0,0,12))
        sarima_fit = sarima_model.fit()
        pred = sarima_fit.predict(exog=df_test[columns], start = df_train.index[-1]+pd.DateOffset(months=1), end = df_train.index[-1]+pd.DateOffset(months=1))
        total_rmse += np.sqrt(mean_squared_error(pred, df_test.mean_ovi))
    return(total_rmse/len(cv_datasets))

# %%
forward_chained_validation(cv_datasets, ['vegetation_index'])
# Out:
# 2.5074069391611027

# %%
forward_chained_validation(cv_datasets, ['vegetation_index', 'soil_moisture'])
# Out:
# 2.311366119807336

# %%
forward_chained_validation(cv_datasets, ['vegetation_index', 'soil_moisture', 'fldas_rainfall'])
# Out:
# 2.6231120295460157

# %%
forward_chained_validation(cv_datasets, ['vegetation_index', 'soil_moisture', 'fldas_rainfall', 'specific_humidity'])
# Out:
# 2.973771522462703

# %%
forward_chained_validation(cv_datasets, ['vegetation_index', 'land_surface_temperature_day'])
# Out:
# 2.2264116619670786

# %%
forward_chained_validation(cv_datasets, ['vegetation_index', 'soil_moisture', 'land_surface_temperature_day'])
# Out:
# 2.3607307756966582
